# %%
import torch
import torchvision
from torchvision.models import resnet50

from kiss.experiment import Experiment
from kiss.sampler import OpticsSampler
from kiss.utils.configs import CONFIGS

transform = torchvision.transforms.ToTensor()
dataset_tr = torchvision.datasets.CIFAR10(root='../data', train=True, download=True, transform=transform)
dataset_te = torchvision.datasets.CIFAR10(root='../data', train=False, download=True, transform=transform)

model = resnet50(num_classes=10)
model.to(torch.device(CONFIGS.torch.device))

experiment = Experiment(
    model, 
    dataset_tr,
    dataset_te, 
    OpticsSampler, 
    ratio=(0.1, 1, 10),
    epochs=10,
    batch_size=256,
    clip=5.0)

experiment.run("../experiments", "r50,epochs:10,bs:256,clipping,eqsize")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Running experiment ResNet!CIFAR10!OpticsSampler
# Running run r50,epochs:10,bs:256,clipping,eqsize/1
# Predicting first optics
# labels 29
# Predicting first optics
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 26
#      14 model.to(torch.device(CONFIGS.torch.device))
#      16 experiment = Experiment(
#      17     model,
#      18     dataset_tr,
#    (...)
#      23     batch_size=256,
#      24     clip=5.0)
# ---> 26 experiment.run("../experiments", "r50,epochs:10,bs:256,clipping,eqsize")
#
# File ~/GitHub/KISS/src/kiss/experiment/base.py:81, in Experiment.run(self, savepath, name)
#      78     os.makedirs(self.run_savepath_)
#      80 self.model = deepcopy(self.model_)
# ---> 81 self._train(ratio)
#      82 self._test()
#
# File ~/GitHub/KISS/src/kiss/experiment/base.py:85, in Experiment._train(self, ratio)
#      84 def _train(self, ratio: float):
# ---> 85     sampler_tr = self.sampler_cls(self.dataset_tr_, ratio, **self.kwargs)
#      87     num_train = int(0.8 * len(sampler_tr))
#      88     num_valid = len(sampler_tr) - num_train
#
# File ~/GitHub/KISS/src/kiss/sampler/optics.py:13, in OpticsSampler.__init__(self, dataset, ratio, **kwargs)
#      10 super().__init__(dataset, ratio)
#      12 class_data = self._get_class_data()
# ---> 13 cluster_data = self._get_cluster_data(class_data)
#      15 num_samples = int(len(dataset) * ratio)
#      16 num_samples_per_cluster = max(2, int(len(dataset) * ratio / len(class_data) / num_clusters))
#
# File ~/GitHub/KISS/src/kiss/sampler/optics.py:64, in OpticsSampler._get_cluster_data(self, class_data)
#      62 data = [self.dataset_[i][0].numpy().flatten() for i in indices]
#      63 optics = OPTICS(min_samples=3, n_jobs=-1)
# ---> 64 labels = optics.fit_predict(data)
#      65 cluster_data[label] = labels
#      66 print("labels", len(set(labels)))
#
# File ~/mambaforge/envs/kiss/lib/python3.11/site-packages/sklearn/base.py:791, in ClusterMixin.fit_predict(self, X, y)
#     773 """
#     774 Perform clustering on `X` and returns cluster labels.
#     775
#    (...)
#     787     Cluster labels.
#     788 """
#     789 # non-optimized default implementation; override when a better
#     790 # method is possible for a given clustering algorithm
# --> 791 self.fit(X)
#     792 return self.labels_
#
# File ~/mambaforge/envs/kiss/lib/python3.11/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~/mambaforge/envs/kiss/lib/python3.11/site-packages/sklearn/cluster/_optics.py:348, in OPTICS.fit(self, X, y)
#     340         X.setdiag(X.diagonal())
#     341 memory = check_memory(self.memory)
#     343 (
#     344     self.ordering_,
#     345     self.core_distances_,
#     346     self.reachability_,
#     347     self.predecessor_,
# --> 348 ) = memory.cache(compute_optics_graph)(
#     349     X=X,
#     350     min_samples=self.min_samples,
#     351     algorithm=self.algorithm,
#     352     leaf_size=self.leaf_size,
#     353     metric=self.metric,
#     354     metric_params=self.metric_params,
#     355     p=self.p,
#     356     n_jobs=self.n_jobs,
#     357     max_eps=self.max_eps,
#     358 )
#     360 # Extract clusters from the calculated orders and reachability
#     361 if self.cluster_method == "xi":
#
# File ~/mambaforge/envs/kiss/lib/python3.11/site-packages/joblib/memory.py:353, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     352 def __call__(self, *args, **kwargs):
# --> 353     return self.func(*args, **kwargs)
#
# File ~/mambaforge/envs/kiss/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:214, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208 try:
#     209     with config_context(
#     210         skip_parameter_validation=(
#     211             prefer_skip_nested_validation or global_skip_validation
#     212         )
#     213     ):
# --> 214         return func(*args, **kwargs)
#     215 except InvalidParameterError as e:
#     216     # When the function is just a wrapper around an estimator, we allow
#     217     # the function to delegate validation to the estimator, but we replace
#     218     # the name of the estimator by the name of the function in the error
#     219     # message to avoid confusion.
#     220     msg = re.sub(
#     221         r"parameter of \w+ must be",
#     222         f"parameter of {func.__qualname__} must be",
#     223         str(e),
#     224     )
#
# File ~/mambaforge/envs/kiss/lib/python3.11/site-packages/sklearn/cluster/_optics.py:617, in compute_optics_graph(X, min_samples, max_eps, metric, p, metric_params, algorithm, leaf_size, n_jobs)
#     615     ordering[ordering_idx] = point
#     616     if core_distances_[point] != np.inf:
# --> 617         _set_reach_dist(
#     618             core_distances_=core_distances_,
#     619             reachability_=reachability_,
#     620             predecessor_=predecessor_,
#     621             point_index=point,
#     622             processed=processed,
#     623             X=X,
#     624             nbrs=nbrs,
#     625             metric=metric,
#     626             metric_params=metric_params,
#     627             p=p,
#     628             max_eps=max_eps,
#     629         )
#     630 if np.all(np.isinf(reachability_)):
#     631     warnings.warn(
#     632         (
#     633             "All reachability values are inf. Set a larger"
#    (...)
#     636         UserWarning,
#     637     )
#
# File ~/mambaforge/envs/kiss/lib/python3.11/site-packages/sklearn/cluster/_optics.py:658, in _set_reach_dist(core_distances_, reachability_, predecessor_, point_index, processed, X, nbrs, metric, metric_params, p, max_eps)
#     654 P = X[point_index : point_index + 1]
#     655 # Assume that radius_neighbors is faster without distances
#     656 # and we don't need all distances, nevertheless, this means
#     657 # we may be doing some work twice.
# --> 658 indices = nbrs.radius_neighbors(P, radius=max_eps, return_distance=False)[0]
#     660 # Getting indices of neighbors that have not been processed
#     661 unproc = np.compress(~np.take(processed, indices), indices)
#
# File ~/mambaforge/envs/kiss/lib/python3.11/site-packages/sklearn/neighbors/_base.py:1159, in RadiusNeighborsMixin.radius_neighbors(self, X, radius, return_distance, sort_results)
#    1151 use_pairwise_distances_reductions = (
#    1152     self._fit_method == "brute"
#    1153     and RadiusNeighbors.is_usable_for(
#    1154         X if X is not None else self._fit_X, self._fit_X, self.effective_metric_
#    1155     )
#    1156 )
#    1158 if use_pairwise_distances_reductions:
# -> 1159     results = RadiusNeighbors.compute(
#    1160         X=X,
#    1161         Y=self._fit_X,
#    1162         radius=radius,
#    1163         metric=self.effective_metric_,
#    1164         metric_kwargs=self.effective_metric_params_,
#    1165         strategy="auto",
#    1166         return_distance=return_distance,
#    1167         sort_results=sort_results,
#    1168     )
#    1170 elif (
#    1171     self._fit_method == "brute" and self.metric == "precomputed" and issparse(X)
#    1172 ):
#    1173     results = _radius_neighbors_from_graph(
#    1174         X, radius=radius, return_distance=return_distance
#    1175     )
#
# File ~/mambaforge/envs/kiss/lib/python3.11/site-packages/sklearn/metrics/_pairwise_distances_reduction/_dispatcher.py:403, in RadiusNeighbors.compute(cls, X, Y, radius, metric, chunk_size, metric_kwargs, strategy, return_distance, sort_results)
#     317 """Return the results of the reduction for the given arguments.
#     318
#     319 Parameters
#    (...)
#     400 returns.
#     401 """
#     402 if X.dtype == Y.dtype == np.float64:
# --> 403     return RadiusNeighbors64.compute(
#     404         X=X,
#     405         Y=Y,
#     406         radius=radius,
#     407         metric=metric,
#     408         chunk_size=chunk_size,
#     409         metric_kwargs=metric_kwargs,
#     410         strategy=strategy,
#     411         sort_results=sort_results,
#     412         return_distance=return_distance,
#     413     )
#     415 if X.dtype == Y.dtype == np.float32:
#     416     return RadiusNeighbors32.compute(
#     417         X=X,
#     418         Y=Y,
#    (...)
#     425         return_distance=return_distance,
#     426     )
#
# File sklearn/metrics/_pairwise_distances_reduction/_radius_neighbors.pyx:120, in sklearn.metrics._pairwise_distances_reduction._radius_neighbors.RadiusNeighbors64.compute()
#
# File ~/mambaforge/envs/kiss/lib/python3.11/site-packages/threadpoolctl.py:440, in _ThreadpoolLimiter.__exit__(self, type, value, traceback)
#     437 def __enter__(self):
#     438     return self
# --> 440 def __exit__(self, type, value, traceback):
#     441     self.restore_original_limits()
#     443 @classmethod
#     444 def wrap(cls, controller, *, limits=None, user_api=None):
#
# KeyboardInterrupt:
